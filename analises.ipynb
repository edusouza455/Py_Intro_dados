# %%
import pandas as pd

caminhoDoc = 'viagens/2024_Viagem.csv'

# %%
df_viagens = pd.read_csv(caminhoDoc, encoding="Windows-1252", sep=";" )    

pd.set_option('display.max_columns', None)

# %%
df_viagens
# Out:
#         Identificador do processo de viagem Número da Proposta (PCDP)  \
# 0                                  18831091                 000011/24
# 1                                  18831495                 000001/24
# 2                                  18831777                 000002/24
# 3                                  18831821                 000003/24
# 4                                  19177818              000001/24-1C
# ...                                     ...                       ...
# 522246                           2024001383             Sem informaçã
# 522247                           2024001392             Sem informaçã
# 522248                           2024001401             Sem informaçã
# 522249                           2024001440             Sem informaçã
# 522250                           2024001455             Sem informaçã
#
#          Situação Viagem Urgente Justificativa Urgência Viagem  \
# ...

# %%
df_viagens['Nome']
# Out:
# 0                     RICARDO DOS SANTOS PEREIRA
# 1                       LETICIA SANCHEZ FERREIRA
# 2                       LETICIA SANCHEZ FERREIRA
# 3                       LETICIA SANCHEZ FERREIRA
# 4                VIRGINIA MARIA VASCONCELOS LEAL
#                            ...
# 522246                  VIVIANE HELENA TORINELLI
# 522247    CARLOS EDUARDO DE ANDRADE BRANDT SILVA
# 522248                ALESSANDRA BARROS MONTEIRO
# 522249                     OTAVIO RIBEIRO DAMASO
# 522250          JOSE REYNALDO DE ALMEIDA FURLANI
# Name: Nome, Length: 522251, dtype: object

# %%
df_viagens['CPF viajante']
# Out:
# 0         ***.405.257-**
# 1         ***.587.016-**
# 2         ***.587.016-**
# 3         ***.587.016-**
# 4         ***.626.601-**
#                ...
# 522246    ***.321.949-**
# 522247    ***.317.891-**
# 522248    ***.915.716-**
# 522249    ***.686.231-**
# 522250    ***.491.441-**
# Name: CPF viajante, Length: 522251, dtype: object

# %%
colunas = ['Nome', 'Cargo','CPF viajante', 'Nome do órgão superior']
df_viagens[colunas]
# Out:
#                                           Nome  \
# 0                   RICARDO DOS SANTOS PEREIRA
# 1                     LETICIA SANCHEZ FERREIRA
# 2                     LETICIA SANCHEZ FERREIRA
# 3                     LETICIA SANCHEZ FERREIRA
# 4              VIRGINIA MARIA VASCONCELOS LEAL
# ...                                        ...
# 522246                VIVIANE HELENA TORINELLI
# 522247  CARLOS EDUARDO DE ANDRADE BRANDT SILVA
# 522248              ALESSANDRA BARROS MONTEIRO
# 522249                   OTAVIO RIBEIRO DAMASO
# 522250        JOSE REYNALDO DE ALMEIDA FURLANI
#
#                                         Cargo    CPF viajante  \
# 0       PROFESSOR ENS BASICO TECN TECNOLOGICO  ***.405.257-**
# 1            PROFESSOR DO MAGISTERIO SUPERIOR  ***.587.016-**
# 2            PROFESSOR DO MAGISTERIO SUPERIOR  ***.587.016-**
# 3            PROFESSOR DO MAGISTERIO SUPERIOR  ***.587.016-**
# 4            PROFESSOR DO MAGISTERIO SUPERIOR  ***.626.601-**
# ...

# %%
df_viagens['Nome do órgão superior'].str.upper().str.replace('MINISTÉRIO', 'MIN')
# Out:
# 0         MIN DA EDUCAÇÃO
# 1         MIN DA EDUCAÇÃO
# 2         MIN DA EDUCAÇÃO
# 3         MIN DA EDUCAÇÃO
# 4         MIN DA EDUCAÇÃO
#                ...
# 522246     SEM INFORMAÇÃO
# 522247     SEM INFORMAÇÃO
# 522248     SEM INFORMAÇÃO
# 522249     SEM INFORMAÇÃO
# 522250     SEM INFORMAÇÃO
# Name: Nome do órgão superior, Length: 522251, dtype: object

# %%
df_viagens[['Nome','Valor diárias','Valor passagens']]
# Out:
#                                           Nome Valor diárias Valor passagens
# 0                   RICARDO DOS SANTOS PEREIRA        929,18            0,00
# 1                     LETICIA SANCHEZ FERREIRA          0,00            0,00
# 2                     LETICIA SANCHEZ FERREIRA          0,00            0,00
# 3                     LETICIA SANCHEZ FERREIRA          0,00            0,00
# 4              VIRGINIA MARIA VASCONCELOS LEAL      14176,38         6892,31
# ...                                        ...           ...             ...
# 522246                VIVIANE HELENA TORINELLI        975,68            0,00
# 522247  CARLOS EDUARDO DE ANDRADE BRANDT SILVA        349,55            0,00
# 522248              ALESSANDRA BARROS MONTEIRO        574,09         1886,54
# 522249                   OTAVIO RIBEIRO DAMASO       1109,09         1674,99
# 522250        JOSE REYNALDO DE ALMEIDA FURLANI       1063,64            0,00
#
# [522251 rows x 3 columns]

# %%
(df_viagens['Cargo'].value_counts(normalize=True) * 100).rename('Proporcao de viagens').reset_index()
# Out:
#                                         Cargo  Proporcao de viagens
# 0           Informações protegidas por sigilo             25.070402
# 1            PROFESSOR DO MAGISTERIO SUPERIOR              9.437360
# 2       PROFESSOR ENS BASICO TECN TECNOLOGICO              6.244790
# 3         AUDITOR FISCAL FEDERAL AGROPECUARIO              3.855516
# 4                 CONTRATADO LEI 8745/93 - NI              3.475997
# ..                                        ...                   ...
# 777                       OPERADOR DE CONSOLE              0.000303
# 778             AUXILIAR NM - 20 (DEC JUD-ME)              0.000303
# 779     TEC EM ENFERMAGEM SAUDE DO TRAB - 40H              0.000303
# 780       AGENTE DE POLICIA - TERCEIRA CLASSE              0.000303
# 781  PROFESSOR MAGISTERIO SUPERIOR-TEMPORARIO              0.000303
#
# [782 rows x 2 columns]
